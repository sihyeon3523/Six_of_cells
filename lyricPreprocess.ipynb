# %%
import pandas as pd 

from konlpy import tag
from konlpy.corpus import kolaw
from konlpy.utils import pprint 

from hanspell import spell_checker

# %%
import platform

#운영체제에 따라 mecab설치 방법이 다름.
if platform.system() == "Windows":
    try:
        from eunjeon import Mecab
        
    except:
        print("please install eunjeon module")
else:  # Ubuntu일 경우
  try:
    from konlpy.tag import Mecab
  except:
    print("please install Mecab")

# %%
df_dance = pd.read_excel(r'./data_song_scraping_NEW/댄스_500songs.xlsx')
df_rap_hiphop = pd.read_excel(r'./data_song_scraping_NEW/랩_힙합_500songs.xlsx')
df_balad = pd.read_excel(r'./data_song_scraping_NEW/발라드_500songs.xlsx')
df_indi = pd.read_excel(r'./data_song_scraping_NEW/인디음악_500songs.xlsx')

df_fork_blues = pd.read_excel(r'./data_song_scraping_NEW/포크_블루스_500songs.xlsx')
df_r_b = pd.read_excel(r'./data_song_scraping_NEW/RB_Soul_500songs.xlsx')
df_rock_metal = pd.read_excel(r'./data_song_scraping_NEW/록_메탈_500songs.xlsx') 
df_trot_hiphop = pd.read_excel(r'./data_song_scraping_NEW/트로트_500songs.xlsx')

# %%
df_allsongs = pd.concat([df_balad, df_dance, df_fork_blues, df_indi, df_r_b, df_rap_hiphop, df_rock_metal, df_trot_hiphop])

# %%
df_allsongs.describe()
# Out:
#        Title  Artist        Date     Genre Lyric Lyric_ver2
# count   4000    4000        4000      4000  4000       3958
# unique  3407     956        2061        41  3610       3815
# top       고백  볼빨간사춘기  2016.08.29  성인가요/트로트
# freq      14      98          19       489    50          8

# %%
df_allsongs
# Out:
#           Title         Artist        Date       Genre  \
# 0        사랑인가 봐           멜로망스  2022.02.18  발라드, 국내드라마
# 1        나의 X에게             경서  2022.04.24         발라드
# 2          취중고백     김민석 (멜로망스)  2021.12.19         발라드
# 3     사랑은 늘 도망가            임영웅  2021.10.11  발라드, 국내드라마
# 4        듣고 싶을까  MSG워너비(M.O.M)  2022.02.26         발라드
# ..          ...            ...         ...         ...
# 495          애수            진시몬  2004.10.01    성인가요/트로트
# 496  단장의 미아리 고개            송가인  2020.12.26    성인가요/트로트
# 497   어머님 사랑합니다            송가인  2021.05.27    성인가요/트로트
# 498      영동 부르스            송가인  2021.06.13    성인가요/트로트
# 499   일소일소 일노일노            임영웅  2020.04.17    성인가요/트로트
#
#                                                  Lyric  \
# 0
# 1    우리 다시 만날래예쁘게 빛나던모든 추억들이너무 그리워너의 품에 안길래이 밤이 새도록...
# 2    뭐하고 있었니 늦었지만잠시 나올래너의 집 골목에 있는놀이터에 앉아 있어친구들 만나서...
# 3    눈물이 난다 이 길을 걸으면그 사람 손길이 자꾸 생각이 난다붙잡지 못하고 가슴만 떨...
# 4    우리 함께 듣던 그 노랠 듣고 싶을까듣고 나서 잠시 날 생각은 할까아주 혹시라도 넌...
# ..                                                 ...
# 495  아직도 모르겠어 난 정말 꿈이라 생각해야 하는지 너 떠난 그 길목에서 널 기다리는데...
# 496  미아리 눈물고개임이 넘던 이별 고개화약 연기 앞을 가려눈 못 뜨고 헤매일 때당신은 ...
# 497  꽃다운 열아홉에연지 찍고 시집와서손발이 터지도록고생하신 어머님백날을 하루같이자식 걱...
# 498  헤어지기 싫어서 애태우던 그 날 밤피눈물에 얼룩진 그대의 모습어차피 떠나야 할인연이...
# 499  세상사 스무고개 길좋은 날만 있을까이왕이라면 웃으며 살자말처럼 쉽지 않아도일소일소 ...
#
#                                             Lyric_ver2
# 0
# 1    <div class="lyric" id="d_video_summary"><!-- h...
# 2    <div class="lyric" id="d_video_summary"><!-- h...
# 3    <div class="lyric" id="d_video_summary"><!-- h...
# 4    <div class="lyric" id="d_video_summary"><!-- h...
# ..                                                 ...
# 495  <div class="lyric" id="d_video_summary"><!-- h...
# 496  <div class="lyric" id="d_video_summary"><!-- h...
# 497  <div class="lyric" id="d_video_summary"><!-- h...
# 498  <div class="lyric" id="d_video_summary"><!-- h...
# 499  <div class="lyric" id="d_video_summary"><!-- h...
#
# [4000 rows x 6 columns]

# %%
df_allsongs[df_allsongs['Lyric_ver2'] == ' ']
# Out:
#                                    Title             Artist        Date  \
# 0                                 사랑인가 봐               멜로망스  2022.02.18
# 0  That That (prod. & feat. SUGA of BTS)           싸이 (PSY)  2022.04.29
# 0                                  Seoul             볼빨간사춘기  2022.04.20
# 0                                 너를 생각해       주시크 (Joosiq)  2021.09.22
# 0                   정이라고 하자 (Feat. 10CM)  BIG Naughty (서동현)  2022.04.20
# 0                                LOVE me          BE'O (비오)  2022.04.12
# 0                                 TOMBOY            (여자)아이들  2022.03.14
# 0                              이제 나만 믿어요                임영웅  2020.04.03
#
#              Genre Lyric Lyric_ver2
# 0       발라드, 국내드라마
# 0               댄스
# 0     인디음악, 포크/블루스
# 0  R&B;/Soul, 인디음악
# 0         R&B/Soul
# 0             랩/힙합
# 0             록/메탈
# 0         성인가요/트로트

# %%
df_allsongs[df_allsongs['Lyric'] == ' ']
# Out:
#                                                  Title                Artist  \
# 0                                               사랑인가 봐                  멜로망스
# 498                                                그XX              G-DRAGON
# 0                That That (prod. & feat. SUGA of BTS)              싸이 (PSY)
# 0                                                Seoul                볼빨간사춘기
# 374                                             어제 차이고    스텔라장 (Stella Jang)
# 411                                                 찻잔                  노고지리
# 414                                          바람아 멈추어다오                   이지연
# 0                                               너를 생각해          주시크 (Joosiq)
# 79                                                 곡예사                   조광일
# 117                                             진인사대천명                   호미들
# 122                           Life is Wet (feat. JMIN)                  CAMO
# 172                              Wifey (feat. 사이먼 도미닉)                  CAMO
# 234                       작두 (Feat. 넉살, Huckleberry P)                  딥플로우
# 335                                         Drive Thru             블루 (BLOO)
# 349                                   100 (Feat. 천재노창)       블랙넛 (Black Nut)
# 417                    I Could Do Dead (Feat. JUSTHIS)              Dbo (디보)
# 483                                       봄날, 벚꽃 그리고 너              에피톤 프로젝트
# 498  T.T.C (Feat. Skinny Brown, ASH ISLAND, Leellam...  Jayci yucca (제이씨 유카)
# 0                                 정이라고 하자 (Feat. 10CM)     BIG Naughty (서동현)
# 477                                          domythang            SINDOSI:22
# 0                                              LOVE me             BE'O (비오)
# 79                       몸매 (MOMMAE) (Feat. Ugly Duck)                   박재범
# 106                                               BAND          창모 (CHANGMO)
# 142                                     BROKEN FERRARI                   호미들
# 156                                                곡예사                   조광일
# 158                   Selfmade Orange (Feat. SUPERBEE)          창모 (CHANGMO)
# 196                                     사랑은(Feat.원슈타인)                   마미손
# 197                              300(prod. Cashbanger)                   호미들
# 220                                             IndiGO        저스디스 (JUSTHIS)
# 222                                    마에스트로 (Maestro)          창모 (CHANGMO)
# 254                                             진인사대천명                   호미들
# 258                               아이야 (Feat. Beenzino)          창모 (CHANGMO)
# 264                           Life is Wet (feat. JMIN)                  CAMO
# 265                    노땡큐 (Feat. MINO, 사이먼 도미닉, 더콰이엇)      에픽하이 (EPIK HIGH)
# 268                TV를 껐네... (Feat. t윤미래, 권정열 Of 10cm)                    리쌍
# 275                                              Gucci            제시 (Jessi)
# 290                                 유레카 (Feat. Zion.T)             지코 (ZICO)
# 307                                사장님 도박은 재미로 하셔야 합니다             비비 (BIBI)
# 346             존시나 (Feat. Northfacegawd, JUSTHIS, 래원)                    염따
# 357     BORN HATER (Feat. 빈지노, 버벌진트, B.I, MINO, BOBBY)      에픽하이 (EPIK HIGH)
# 394                       GENERATION (Prod. Lean$moke)                   호미들
# 418                                   거북선 (Feat. 팔로알토)               Ja Mezz
# 424                                 냉탕에 상어 (Feat. 블랙넛)        수퍼비 (SUPERBEE)
# 452                              Better Than Yesterday               MC 스나이퍼
# 453                         범퍼카 (Feat. NO:EL, Young B)                   한요한
# 462                              Wifey (feat. 사이먼 도미닉)                  CAMO
# 485                                             집에 가지마                GD&TOP
# 497                                    문제아 (Full Ver.)        수퍼비 (SUPERBEE)
# 0                                               TOMBOY               (여자)아이들
# 0                                            이제 나만 믿어요                   임영웅
#
#            Date            Genre Lyric Lyric_ver2
# 0    2022.02.18       발라드, 국내드라마
# 498  2012.09.15              발라드              NaN
# 0    2022.04.29               댄스
# 0    2022.04.20     인디음악, 포크/블루스
# 374  2016.10.06     인디음악, 포크/블루스              NaN
# 411  2014.05.14           포크/블루스              NaN
# 414  2014.05.14           포크/블루스              NaN
# 0    2021.09.22  R&B;/Soul, 인디음악
# 79   2020.04.01       랩/힙합, 인디음악              NaN
# 117  2020.01.28       랩/힙합, 인디음악              NaN
# 122  2020.09.02       랩/힙합, 인디음악              NaN
# 172  2021.01.27       랩/힙합, 인디음악              NaN
# 234  2015.04.13       랩/힙합, 인디음악              NaN
# 335  2016.06.18       랩/힙합, 인디음악              NaN
# 349  2014.08.08       랩/힙합, 인디음악              NaN
# 417  2019.03.09       랩/힙합, 인디음악              NaN
# 483  2009.02.24        발라드, 인디음악              NaN
# 498  2019.05.15       랩/힙합, 인디음악              NaN
# 0    2022.04.20         R&B/Soul
# 477  2022.03.24         R&B/Soul              NaN
# 0    2022.04.12             랩/힙합
# 79   2015.05.22             랩/힙합              NaN
# 106  2019.06.08             랩/힙합              NaN
# 142  2022.03.08             랩/힙합              NaN
# 156  2020.04.01       랩/힙합, 인디음악              NaN
# 158  2018.06.11             랩/힙합              NaN
# 196  2019.11.18             랩/힙합              NaN
# 197  2020.12.14             랩/힙합              NaN
# 220  2018.06.24             랩/힙합              NaN
# 222  2016.07.21             랩/힙합              NaN
# 254  2020.01.28       랩/힙합, 인디음악              NaN
# 258  2016.12.15             랩/힙합              NaN
# 264  2020.09.02       랩/힙합, 인디음악              NaN
# 265  2017.10.23             랩/힙합              NaN
# 268  2011.08.25        발라드, 랩/힙합              NaN
# 275  2017.07.13             랩/힙합              NaN
# 290  2015.12.07             랩/힙합              NaN
# 307  2020.04.29             랩/힙합              NaN
# 346  2020.11.28             랩/힙합              NaN
# 357  2014.10.21             랩/힙합              NaN
# 394  2021.12.14             랩/힙합              NaN
# 418  2015.08.01             랩/힙합              NaN
# 424  2015.10.26             랩/힙합              NaN
# 452  2007.03.05             랩/힙합              NaN
# 453  2018.01.29             랩/힙합              NaN
# 462  2021.01.27       랩/힙합, 인디음악              NaN
# 485  2010.12.24             랩/힙합              NaN
# 497  2019.04.03             랩/힙합              NaN
# 0    2022.03.14             록/메탈
# 0    2020.04.03         성인가요/트로트

# %% [markdown]
# 나중에 빈 곡 채워넣기!!! 일단 빈 곡 빼고 시작!

# %%
## 나중에 빈 곡 채워넣기!

# a = """
# 빠끄
# """

# a  = a.replace('\n\n', ' ')

# a = a.replace("\n", ' ')

# df.iloc[348]['Lyric'] = a

# %%
# df_allsongs = df_allsongs[df_allsongs['Lyric_ver2'] != ' ']
# df_allsongs.describe()

# %%
# # 일단 빈칸 제거 
df_allsongs = df_allsongs[df_allsongs['Lyric'] != ' ']
df_allsongs.describe()
# Out:
#        Title  Artist        Date     Genre  \
# count   3950    3950        3950      3950
# unique  3364     947        2046        41
# top       고백  볼빨간사춘기  2016.08.29  성인가요/트로트
# freq      14      97          19       488
#
#                                                     Lyric  \
# count                                                3950
# unique                                               3609
# top     소란했던 오늘의 하루가너와 함께 고요해작은 입술을 열어우리의 밤을 노래해넌 내가 본...
# freq                                                    3
#
#                                                Lyric_ver2
# count                                                3950
# unique                                               3814
# top     <div class="lyric" id="d_video_summary"><!-- h...
# freq                                                    3

# %%
df_allsongs = df_allsongs.reset_index(drop=True)
df_allsongs
# Out:
#               Title         Artist        Date       Genre  \
# 0            나의 X에게             경서  2022.04.24         발라드
# 1              취중고백     김민석 (멜로망스)  2021.12.19         발라드
# 2         사랑은 늘 도망가            임영웅  2021.10.11  발라드, 국내드라마
# 3            듣고 싶을까  MSG워너비(M.O.M)  2022.02.26         발라드
# 4     다정히 내 이름을 부르면           경서예지  2021.05.19         발라드
# ...             ...            ...         ...         ...
# 3945             애수            진시몬  2004.10.01    성인가요/트로트
# 3946     단장의 미아리 고개            송가인  2020.12.26    성인가요/트로트
# 3947      어머님 사랑합니다            송가인  2021.05.27    성인가요/트로트
# 3948         영동 부르스            송가인  2021.06.13    성인가요/트로트
# 3949      일소일소 일노일노            임영웅  2020.04.17    성인가요/트로트
#
#                                                   Lyric  \
# 0     우리 다시 만날래예쁘게 빛나던모든 추억들이너무 그리워너의 품에 안길래이 밤이 새도록...
# 1     뭐하고 있었니 늦었지만잠시 나올래너의 집 골목에 있는놀이터에 앉아 있어친구들 만나서...
# 2     눈물이 난다 이 길을 걸으면그 사람 손길이 자꾸 생각이 난다붙잡지 못하고 가슴만 떨...
# 3     우리 함께 듣던 그 노랠 듣고 싶을까듣고 나서 잠시 날 생각은 할까아주 혹시라도 넌...
# 4     끝없이 별빛이 내리던 밤기분 좋은 바람이두 빰을 스치고새벽 바다 한곳을 보는아름다운...
# ...                                                 ...
# 3945  아직도 모르겠어 난 정말 꿈이라 생각해야 하는지 너 떠난 그 길목에서 널 기다리는데...
# 3946  미아리 눈물고개임이 넘던 이별 고개화약 연기 앞을 가려눈 못 뜨고 헤매일 때당신은 ...
# 3947  꽃다운 열아홉에연지 찍고 시집와서손발이 터지도록고생하신 어머님백날을 하루같이자식 걱...
# 3948  헤어지기 싫어서 애태우던 그 날 밤피눈물에 얼룩진 그대의 모습어차피 떠나야 할인연이...
# 3949  세상사 스무고개 길좋은 날만 있을까이왕이라면 웃으며 살자말처럼 쉽지 않아도일소일소 ...
#
#                                              Lyric_ver2
# 0     <div class="lyric" id="d_video_summary"><!-- h...
# 1     <div class="lyric" id="d_video_summary"><!-- h...
# 2     <div class="lyric" id="d_video_summary"><!-- h...
# 3     <div class="lyric" id="d_video_summary"><!-- h...
# 4     <div class="lyric" id="d_video_summary"><!-- h...
# ...                                                 ...
# 3945  <div class="lyric" id="d_video_summary"><!-- h...
# 3946  <div class="lyric" id="d_video_summary"><!-- h...
# 3947  <div class="lyric" id="d_video_summary"><!-- h...
# 3948  <div class="lyric" id="d_video_summary"><!-- h...
# 3949  <div class="lyric" id="d_video_summary"><!-- h...
#
# [3950 rows x 6 columns]

# %%
df_allsongs['Lyric'].nunique() 
# df_allsongs : 장르별 df 다 합친 것
# nunique: n of unique, 데이터 중복 유무를 확인

df_allsongs.drop_duplicates(subset = ['Lyric'], inplace = True)
len(df_allsongs)
# Out:
# 3609

# %%
df_allsongs = df_allsongs.reset_index(drop=True)
df_allsongs
# Out:
#               Title         Artist        Date       Genre  \
# 0            나의 X에게             경서  2022.04.24         발라드
# 1              취중고백     김민석 (멜로망스)  2021.12.19         발라드
# 2         사랑은 늘 도망가            임영웅  2021.10.11  발라드, 국내드라마
# 3            듣고 싶을까  MSG워너비(M.O.M)  2022.02.26         발라드
# 4     다정히 내 이름을 부르면           경서예지  2021.05.19         발라드
# ...             ...            ...         ...         ...
# 3604             애수            진시몬  2004.10.01    성인가요/트로트
# 3605     단장의 미아리 고개            송가인  2020.12.26    성인가요/트로트
# 3606      어머님 사랑합니다            송가인  2021.05.27    성인가요/트로트
# 3607         영동 부르스            송가인  2021.06.13    성인가요/트로트
# 3608      일소일소 일노일노            임영웅  2020.04.17    성인가요/트로트
#
#                                                   Lyric  \
# 0     우리 다시 만날래예쁘게 빛나던모든 추억들이너무 그리워너의 품에 안길래이 밤이 새도록...
# 1     뭐하고 있었니 늦었지만잠시 나올래너의 집 골목에 있는놀이터에 앉아 있어친구들 만나서...
# 2     눈물이 난다 이 길을 걸으면그 사람 손길이 자꾸 생각이 난다붙잡지 못하고 가슴만 떨...
# 3     우리 함께 듣던 그 노랠 듣고 싶을까듣고 나서 잠시 날 생각은 할까아주 혹시라도 넌...
# 4     끝없이 별빛이 내리던 밤기분 좋은 바람이두 빰을 스치고새벽 바다 한곳을 보는아름다운...
# ...                                                 ...
# 3604  아직도 모르겠어 난 정말 꿈이라 생각해야 하는지 너 떠난 그 길목에서 널 기다리는데...
# 3605  미아리 눈물고개임이 넘던 이별 고개화약 연기 앞을 가려눈 못 뜨고 헤매일 때당신은 ...
# 3606  꽃다운 열아홉에연지 찍고 시집와서손발이 터지도록고생하신 어머님백날을 하루같이자식 걱...
# 3607  헤어지기 싫어서 애태우던 그 날 밤피눈물에 얼룩진 그대의 모습어차피 떠나야 할인연이...
# 3608  세상사 스무고개 길좋은 날만 있을까이왕이라면 웃으며 살자말처럼 쉽지 않아도일소일소 ...
#
#                                              Lyric_ver2
# 0     <div class="lyric" id="d_video_summary"><!-- h...
# 1     <div class="lyric" id="d_video_summary"><!-- h...
# 2     <div class="lyric" id="d_video_summary"><!-- h...
# 3     <div class="lyric" id="d_video_summary"><!-- h...
# 4     <div class="lyric" id="d_video_summary"><!-- h...
# ...                                                 ...
# 3604  <div class="lyric" id="d_video_summary"><!-- h...
# 3605  <div class="lyric" id="d_video_summary"><!-- h...
# 3606  <div class="lyric" id="d_video_summary"><!-- h...
# 3607  <div class="lyric" id="d_video_summary"><!-- h...
# 3608  <div class="lyric" id="d_video_summary"><!-- h...
#
# [3609 rows x 6 columns]

# %% [markdown]
# 다 긁어온거라 ```<div class>``` 이거 없애야함

# %%
# test
temp = '<div class="lyric" id="d_video_summary"><!-- height:auto; 로 변경시, 확장됨 --> asdfadf         '
temp = temp.replace('<div class="lyric" id="d_video_summary"><!-- height:auto; 로 변경시, 확장됨 -->', "").strip()
temp
# Out:
# 'asdfadf'

# %%
temp = df_allsongs.Lyric_ver2.iloc[1]
print(temp)

print()
print(type(temp))
# Out:
# <div class="lyric" id="d_video_summary"><!-- height:auto; 로 변경시, 확장됨 -->
# 							뭐하고 있었니 늦었지만<br/>잠시 나올래<br/>너의 집 골목에 있는<br/>놀이터에 앉아 있어<br/>친구들 만나서 오랜만에<br/>술을 좀 했는데<br/>자꾸만 니 얼굴 떠올라<br/>무작정 달려왔어<br/>이 맘 모르겠니<br/>요즘 난 미친 사람처럼<br/>너만 생각해<br/>대책없이 네가 점점 좋아져<br/>아냐 안 취했어 진짜야<br/>널 정말 사랑해<br/>눈물이 날만큼 원하고 있어<br/>정말로 몰랐니<br/>가끔 전화해 장난치듯<br/>주말엔 뭐할거냐며<br/>너의 관심 끌던 나를<br/>그리고 한번씩 누나 주려 샀는데<br/>너 그냥 준다고<br/>생색 낸 선물도 너 때문에 산거야<br/>이 맘 모르겠니<br/>요즘 난 미친 사람처럼<br/>너만 생각해<br/>대책없이 네가 점점 좋아져<br/>아냐 안 취했어 진짜야<br/>널 정말 사랑해<br/>진심이야 믿어줘<br/>갑자기 이런 말 놀랐다면 미안해<br/>부담이 되는게 당연해<br/>이해해 널<br/>하지만 내 고백도 이해해 주겠니 oh<br/>지금 당장 대답하진마<br/>나와 일주일만 사귀어줄래<br/>후회없이 잘 해주고 싶은데<br/>그 후에도 니가 싫다면<br/>나 그때 포기할게<br/>귀찮게 안할게 혼자 아플게<br/>진심이야 너를 사랑하고 있어<br/>
# </div>
#
# <class 'str'>

# %%
temp = temp.replace('<div class="lyric" id="d_video_summary"><!-- height:auto; 로 변경시, 확장됨 -->', "").strip()
temp = temp.replace('\n</div>', "").strip()
temp
# Out:
# '뭐하고 있었니 늦었지만<br/>잠시 나올래<br/>너의 집 골목에 있는<br/>놀이터에 앉아 있어<br/>친구들 만나서 오랜만에<br/>술을 좀 했는데<br/>자꾸만 니 얼굴 떠올라<br/>무작정 달려왔어<br/>이 맘 모르겠니<br/>요즘 난 미친 사람처럼<br/>너만 생각해<br/>대책없이 네가 점점 좋아져<br/>아냐 안 취했어 진짜야<br/>널 정말 사랑해<br/>눈물이 날만큼 원하고 있어<br/>정말로 몰랐니<br/>가끔 전화해 장난치듯<br/>주말엔 뭐할거냐며<br/>너의 관심 끌던 나를<br/>그리고 한번씩 누나 주려 샀는데<br/>너 그냥 준다고<br/>생색 낸 선물도 너 때문에 산거야<br/>이 맘 모르겠니<br/>요즘 난 미친 사람처럼<br/>너만 생각해<br/>대책없이 네가 점점 좋아져<br/>아냐 안 취했어 진짜야<br/>널 정말 사랑해<br/>진심이야 믿어줘<br/>갑자기 이런 말 놀랐다면 미안해<br/>부담이 되는게 당연해<br/>이해해 널<br/>하지만 내 고백도 이해해 주겠니 oh<br/>지금 당장 대답하진마<br/>나와 일주일만 사귀어줄래<br/>후회없이 잘 해주고 싶은데<br/>그 후에도 니가 싫다면<br/>나 그때 포기할게<br/>귀찮게 안할게 혼자 아플게<br/>진심이야 너를 사랑하고 있어<br/>'

# %%
temp_list = temp.split('<br/>')
type(temp_list)
# Out:
# list

# %%
df_allsongs['preprocess_Lyric_ver2'] = ''

for i in range(len(df_allsongs)): 
    lyric = df_allsongs.Lyric_ver2.iloc[i] 
    lyric = str(lyric)
    lyric = lyric.replace('<div class="lyric" id="d_video_summary"><!-- height:auto; 로 변경시, 확장됨 -->', "").strip() 
    lyric = lyric.replace('_x000D_\n\t\t\t\t\t\t\t', "").strip() 
    lyric = lyric.replace('\r\n\t\t\t\t\t</div>', "").strip()  
    lyric = lyric.replace('\n</div>', "").strip()
    lyric = lyric.replace('<br/>', " ")
    df_allsongs.loc[i, 'preprocess_Lyric_ver2'] = lyric

df_allsongs.head(3)
# Out:
#        Title      Artist        Date       Genre  \
# 0     나의 X에게          경서  2022.04.24         발라드
# 1       취중고백  김민석 (멜로망스)  2021.12.19         발라드
# 2  사랑은 늘 도망가         임영웅  2021.10.11  발라드, 국내드라마
#
#                                                Lyric  \
# 0  우리 다시 만날래예쁘게 빛나던모든 추억들이너무 그리워너의 품에 안길래이 밤이 새도록...
# 1  뭐하고 있었니 늦었지만잠시 나올래너의 집 골목에 있는놀이터에 앉아 있어친구들 만나서...
# 2  눈물이 난다 이 길을 걸으면그 사람 손길이 자꾸 생각이 난다붙잡지 못하고 가슴만 떨...
#
#                                           Lyric_ver2  \
# 0  <div class="lyric" id="d_video_summary"><!-- h...
# 1  <div class="lyric" id="d_video_summary"><!-- h...
# 2  <div class="lyric" id="d_video_summary"><!-- h...
#
#                                preprocess_Lyric_ver2
# 0  우리 다시 만날래 예쁘게 빛나던 모든 추억들이 너무 그리워 너의 품에 안길래 이 밤...
# 1  뭐하고 있었니 늦었지만 잠시 나올래 너의 집 골목에 있는 놀이터에 앉아 있어 친구들...
# 2  눈물이 난다 이 길을 걸으면 그 사람 손길이 자꾸 생각이 난다 붙잡지 못하고 가슴만...

# %%
df_allsongs['preprocess_Lyric_ver3'] = ''


for i in range(len(df_allsongs)): 
    lyric = df_allsongs.Lyric_ver2.iloc[i] 
    
    lyric = str(lyric)
    lyric = lyric.replace('<div class="lyric" id="d_video_summary"><!-- height:auto; 로 변경시, 확장됨 -->', "").strip() 
    lyric = lyric.replace('_x000D_\n\t\t\t\t\t\t\t', "").strip()
    lyric = lyric.replace('\r\n\t\t\t\t\t</div>', "").strip()  
    lyric = lyric.replace('\n</div>', "").strip()
    
    lyric_list = lyric.split('<br/>')
    
    #print(lyric_list)
    #print(type(lyric_list))
    
    #df_allsongs.loc[i, 'preprocess_Lyric_ver3'] = lyric_list
    
    df_allsongs.at[i, 'preprocess_Lyric_ver3'] = lyric_list
    
    #df_allsongs.iat[i, df_allsongs.columns.get_loc('preprocess_Lyric_ver3')] = lyric_list  
    
    #df_allsongs.iloc[i, 'preprocess_Lyric_ver3'] = lyric_list

# %%
df_allsongs
# Out:
#               Title         Artist        Date       Genre  \
# 0            나의 X에게             경서  2022.04.24         발라드
# 1              취중고백     김민석 (멜로망스)  2021.12.19         발라드
# 2         사랑은 늘 도망가            임영웅  2021.10.11  발라드, 국내드라마
# 3            듣고 싶을까  MSG워너비(M.O.M)  2022.02.26         발라드
# 4     다정히 내 이름을 부르면           경서예지  2021.05.19         발라드
# ...             ...            ...         ...         ...
# 3604             애수            진시몬  2004.10.01    성인가요/트로트
# 3605     단장의 미아리 고개            송가인  2020.12.26    성인가요/트로트
# 3606      어머님 사랑합니다            송가인  2021.05.27    성인가요/트로트
# 3607         영동 부르스            송가인  2021.06.13    성인가요/트로트
# 3608      일소일소 일노일노            임영웅  2020.04.17    성인가요/트로트
#
#                                                   Lyric  \
# 0     우리 다시 만날래예쁘게 빛나던모든 추억들이너무 그리워너의 품에 안길래이 밤이 새도록...
# 1     뭐하고 있었니 늦었지만잠시 나올래너의 집 골목에 있는놀이터에 앉아 있어친구들 만나서...
# 2     눈물이 난다 이 길을 걸으면그 사람 손길이 자꾸 생각이 난다붙잡지 못하고 가슴만 떨...
# 3     우리 함께 듣던 그 노랠 듣고 싶을까듣고 나서 잠시 날 생각은 할까아주 혹시라도 넌...
# 4     끝없이 별빛이 내리던 밤기분 좋은 바람이두 빰을 스치고새벽 바다 한곳을 보는아름다운...
# ...                                                 ...
# 3604  아직도 모르겠어 난 정말 꿈이라 생각해야 하는지 너 떠난 그 길목에서 널 기다리는데...
# 3605  미아리 눈물고개임이 넘던 이별 고개화약 연기 앞을 가려눈 못 뜨고 헤매일 때당신은 ...
# 3606  꽃다운 열아홉에연지 찍고 시집와서손발이 터지도록고생하신 어머님백날을 하루같이자식 걱...
# 3607  헤어지기 싫어서 애태우던 그 날 밤피눈물에 얼룩진 그대의 모습어차피 떠나야 할인연이...
# 3608  세상사 스무고개 길좋은 날만 있을까이왕이라면 웃으며 살자말처럼 쉽지 않아도일소일소 ...
#
#                                              Lyric_ver2  \
# 0     <div class="lyric" id="d_video_summary"><!-- h...
# 1     <div class="lyric" id="d_video_summary"><!-- h...
# 2     <div class="lyric" id="d_video_summary"><!-- h...
# 3     <div class="lyric" id="d_video_summary"><!-- h...
# 4     <div class="lyric" id="d_video_summary"><!-- h...
# ...                                                 ...
# 3604  <div class="lyric" id="d_video_summary"><!-- h...
# 3605  <div class="lyric" id="d_video_summary"><!-- h...
# 3606  <div class="lyric" id="d_video_summary"><!-- h...
# 3607  <div class="lyric" id="d_video_summary"><!-- h...
# 3608  <div class="lyric" id="d_video_summary"><!-- h...
#
#                                   preprocess_Lyric_ver2  \
# 0     우리 다시 만날래 예쁘게 빛나던 모든 추억들이 너무 그리워 너의 품에 안길래 이 밤...
# 1     뭐하고 있었니 늦었지만 잠시 나올래 너의 집 골목에 있는 놀이터에 앉아 있어 친구들...
# 2     눈물이 난다 이 길을 걸으면 그 사람 손길이 자꾸 생각이 난다 붙잡지 못하고 가슴만...
# 3     우리 함께 듣던 그 노랠 듣고 싶을까 듣고 나서 잠시 날 생각은 할까 아주 혹시라도...
# 4     끝없이 별빛이 내리던 밤 기분 좋은 바람이 두 빰을 스치고 새벽 바다 한곳을 보는 ...
# ...                                                 ...
# 3604  아직도 모르겠어 난 정말   꿈이라 생각해야 하는지   너 떠난 그 길목에서  널 ...
# 3605  미아리 눈물고개 임이 넘던 이별 고개 화약 연기 앞을 가려 눈 못 뜨고 헤매일 때 ...
# 3606  꽃다운 열아홉에 연지 찍고 시집와서 손발이 터지도록 고생하신 어머님 백날을 하루같이...
# 3607  헤어지기 싫어서 애태우던 그 날 밤 피눈물에 얼룩진 그대의 모습 어차피 떠나야 할 ...
# 3608  세상사 스무고개 길 좋은 날만 있을까 이왕이라면 웃으며 살자 말처럼 쉽지 않아도 일...
#
#                                   preprocess_Lyric_ver3
# 0     [우리 다시 만날래, 예쁘게 빛나던, 모든 추억들이, 너무 그리워, 너의 품에 안길...
# 1     [뭐하고 있었니 늦었지만, 잠시 나올래, 너의 집 골목에 있는, 놀이터에 앉아 있어...
# 2     [눈물이 난다 이 길을 걸으면, 그 사람 손길이 자꾸 생각이 난다, 붙잡지 못하고 ...
# 3     [우리 함께 듣던 그 노랠 듣고 싶을까, 듣고 나서 잠시 날 생각은 할까, 아주 혹...
# 4     [끝없이 별빛이 내리던 밤, 기분 좋은 바람이, 두 빰을 스치고, 새벽 바다 한곳을...
# ...                                                 ...
# 3604  [아직도 모르겠어 난 정말 , , 꿈이라 생각해야 하는지 , , 너 떠난 그 길목에...
# 3605  [미아리 눈물고개, 임이 넘던 이별 고개, 화약 연기 앞을 가려, 눈 못 뜨고 헤매...
# 3606  [꽃다운 열아홉에, 연지 찍고 시집와서, 손발이 터지도록, 고생하신 어머님, 백날을...
# 3607  [헤어지기 싫어서 애태우던 그 날 밤, 피눈물에 얼룩진 그대의 모습, 어차피 떠나야...
# 3608  [세상사 스무고개 길, 좋은 날만 있을까, 이왕이라면 웃으며 살자, 말처럼 쉽지 않...
#
# [3609 rows x 8 columns]

# %% [markdown]
# Save df_allsongs to CSV

# %%
df_allsongs.to_csv('df_allsongs.csv')

# %%
temp = pd.read_csv('df_allsongs.csv', lineterminator = '\n')
temp
# Out:
#       Unnamed: 0          Title         Artist        Date       Genre  \
# 0              0         나의 X에게             경서  2022.04.24         발라드
# 1              1           취중고백     김민석 (멜로망스)  2021.12.19         발라드
# 2              2      사랑은 늘 도망가            임영웅  2021.10.11  발라드, 국내드라마
# 3              3         듣고 싶을까  MSG워너비(M.O.M)  2022.02.26         발라드
# 4              4  다정히 내 이름을 부르면           경서예지  2021.05.19         발라드
# ...          ...            ...            ...         ...         ...
# 3604        3604             애수            진시몬  2004.10.01    성인가요/트로트
# 3605        3605     단장의 미아리 고개            송가인  2020.12.26    성인가요/트로트
# 3606        3606      어머님 사랑합니다            송가인  2021.05.27    성인가요/트로트
# 3607        3607         영동 부르스            송가인  2021.06.13    성인가요/트로트
# 3608        3608      일소일소 일노일노            임영웅  2020.04.17    성인가요/트로트
#
#                                                   Lyric  \
# 0     우리 다시 만날래예쁘게 빛나던모든 추억들이너무 그리워너의 품에 안길래이 밤이 새도록...
# 1     뭐하고 있었니 늦었지만잠시 나올래너의 집 골목에 있는놀이터에 앉아 있어친구들 만나서...
# 2     눈물이 난다 이 길을 걸으면그 사람 손길이 자꾸 생각이 난다붙잡지 못하고 가슴만 떨...
# 3     우리 함께 듣던 그 노랠 듣고 싶을까듣고 나서 잠시 날 생각은 할까아주 혹시라도 넌...
# 4     끝없이 별빛이 내리던 밤기분 좋은 바람이두 빰을 스치고새벽 바다 한곳을 보는아름다운...
# ...                                                 ...
# 3604  아직도 모르겠어 난 정말 꿈이라 생각해야 하는지 너 떠난 그 길목에서 널 기다리는데...
# 3605  미아리 눈물고개임이 넘던 이별 고개화약 연기 앞을 가려눈 못 뜨고 헤매일 때당신은 ...
# 3606  꽃다운 열아홉에연지 찍고 시집와서손발이 터지도록고생하신 어머님백날을 하루같이자식 걱...
# 3607  헤어지기 싫어서 애태우던 그 날 밤피눈물에 얼룩진 그대의 모습어차피 떠나야 할인연이...
# 3608  세상사 스무고개 길좋은 날만 있을까이왕이라면 웃으며 살자말처럼 쉽지 않아도일소일소 ...
#
#                                              Lyric_ver2  \
# 0     <div class="lyric" id="d_video_summary"><!-- h...
# 1     <div class="lyric" id="d_video_summary"><!-- h...
# 2     <div class="lyric" id="d_video_summary"><!-- h...
# 3     <div class="lyric" id="d_video_summary"><!-- h...
# 4     <div class="lyric" id="d_video_summary"><!-- h...
# ...                                                 ...
# 3604  <div class="lyric" id="d_video_summary"><!-- h...
# 3605  <div class="lyric" id="d_video_summary"><!-- h...
# 3606  <div class="lyric" id="d_video_summary"><!-- h...
# 3607  <div class="lyric" id="d_video_summary"><!-- h...
# 3608  <div class="lyric" id="d_video_summary"><!-- h...
#
#                                   preprocess_Lyric_ver2  \
# 0     우리 다시 만날래 예쁘게 빛나던 모든 추억들이 너무 그리워 너의 품에 안길래 이 밤...
# 1     뭐하고 있었니 늦었지만 잠시 나올래 너의 집 골목에 있는 놀이터에 앉아 있어 친구들...
# 2     눈물이 난다 이 길을 걸으면 그 사람 손길이 자꾸 생각이 난다 붙잡지 못하고 가슴만...
# 3     우리 함께 듣던 그 노랠 듣고 싶을까 듣고 나서 잠시 날 생각은 할까 아주 혹시라도...
# 4     끝없이 별빛이 내리던 밤 기분 좋은 바람이 두 빰을 스치고 새벽 바다 한곳을 보는 ...
# ...                                                 ...
# 3604  아직도 모르겠어 난 정말   꿈이라 생각해야 하는지   너 떠난 그 길목에서  널 ...
# 3605  미아리 눈물고개 임이 넘던 이별 고개 화약 연기 앞을 가려 눈 못 뜨고 헤매일 때 ...
# 3606  꽃다운 열아홉에 연지 찍고 시집와서 손발이 터지도록 고생하신 어머님 백날을 하루같이...
# 3607  헤어지기 싫어서 애태우던 그 날 밤 피눈물에 얼룩진 그대의 모습 어차피 떠나야 할 ...
# 3608  세상사 스무고개 길 좋은 날만 있을까 이왕이라면 웃으며 살자 말처럼 쉽지 않아도 일...
#
#                                   preprocess_Lyric_ver3
# 0     ['우리 다시 만날래', '예쁘게 빛나던', '모든 추억들이', '너무 그리워', ...
# 1     ['뭐하고 있었니 늦었지만', '잠시 나올래', '너의 집 골목에 있는', '놀이터...
# 2     ['눈물이 난다 이 길을 걸으면', '그 사람 손길이 자꾸 생각이 난다', '붙잡지...
# 3     ['우리 함께 듣던 그 노랠 듣고 싶을까', '듣고 나서 잠시 날 생각은 할까', ...
# 4     ['끝없이 별빛이 내리던 밤', '기분 좋은 바람이', '두 빰을 스치고', '새벽...
# ...                                                 ...
# 3604  ['아직도 모르겠어 난 정말 ', '', '꿈이라 생각해야 하는지 ', '', '너...
# 3605  ['미아리 눈물고개', '임이 넘던 이별 고개', '화약 연기 앞을 가려', '눈 ...
# 3606  ['꽃다운 열아홉에', '연지 찍고 시집와서', '손발이 터지도록', '고생하신 어...
# 3607  ['헤어지기 싫어서 애태우던 그 날 밤', '피눈물에 얼룩진 그대의 모습', '어차...
# 3608  ['세상사 스무고개 길', '좋은 날만 있을까', '이왕이라면 웃으며 살자', '말...
#
# [3609 rows x 9 columns]

# %% [markdown]
# 가사에서 영어 50% 넘으면 삭제

# %%
# def drop_if_eng(df): 
#     df['one_string'] = df['Lyric'].str.join(" ") 
#     mecab = Mecab() 
#     for i in df.one_string:
#         sents = mecab.pos(i) 
#         n = 0 # n: SL(외국어)태그의 숫자
#         result = []
#         for word in sents:
#             if word[1] == 'SL': # SL: Mecab에서 외국어 의미
#                 n += 1
#         if n > (len(sents)//2): # 50% 넘으면 제거 
#             df = df[df.one_string != i] 
#             #print(len(df)) 
#     return df

# %%
# df_saved = drop_if_eng(df_allsongs)

# %%
# df_saved.describe()

# %%
# df_woeng = df_saved[['Title', 'Artist', 'Date', 'Genre', 'one_string']] # dataframe without english
# df_woeng.one_string = df_woeng.one_string.str.replace(" ", '')
# df_woeng

# %% [markdown]
# TRIVIA

# %%
# for row in df_woeng.iterrows():
#   #타이틀 print(row[1][0])
#   #아티스트 print(row[1][1])
#   #가사 print(row[1][-1])

#   print("Artist: {} Title: {}".format(row[1][1], row[1][0]))

# %%
# # 시현님 제안, lambda x 활용 
# df_woeng['one_string'].apply(lambda x : spell_checker.check(x).checked)

# %%
# # 민주님, 수정님 제안. itterows 활용
# for row in df_woeng.iterrows():
#     lyric = row[1][-1] 
#     spelled_test = spell_checker.check(lyric) 
#     hanspell_test = spelled_test.checked 
#     # lyric = hanspell_test

# %%
# # df_woeng['lyrics_ver2'] = ''
# for i in range(len(df_woeng)+1):
#     lyric = df_woeng.one_string.iloc[i] 
#     spelled_test = spell_checker.check(lyric) 
#     dict_spelled_test = spelled_test.as_dict()
#     hanspell_test = dict_spelled_test['checked']
#     # hanspell_test = spelled_test.checked 
#     # df_woeng.loc[i, 'lyrics_ver2'].append
#     print('--------------------------------------')
#     print(hanspell_test)
